# %% [markdown]
# ## Importing Required Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Data and Preprocessing

# %%
df=pd.read_csv("/content/cirrhosis.csv")

# %%
df.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
df.shape
# Out:
# (418, 20)

# %%
df.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %%
df.tail()
# Out:
#       ID  N_Days Status Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 413  414     681      D  NaN  24472   F     NaN          NaN     NaN     N
# 414  415    1103      C  NaN  14245   F     NaN          NaN     NaN     N
# 415  416    1055      C  NaN  20819   F     NaN          NaN     NaN     N
# 416  417     691      C  NaN  21185   F     NaN          NaN     NaN     N
# 417  418     976      C  NaN  19358   F     NaN          NaN     NaN     N
#
#      Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  SGOT  Tryglicerides  \
# 413        1.2          NaN     2.96     NaN       NaN   NaN            NaN
# 414        0.9          NaN     3.83     NaN       NaN   NaN            NaN
# 415        1.6          NaN     3.42     NaN       NaN   NaN            NaN
# 416        0.8          NaN     3.75     NaN       NaN   NaN            NaN
# 417        0.7          NaN     3.29     NaN       NaN   NaN            NaN
#
#      Platelets  Prothrombin  Stage
# 413      174.0         10.9    3.0
# 414      180.0         11.2    4.0
# 415      143.0          9.9    3.0
# 416      269.0         10.4    3.0
# 417      350.0         10.6    4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
#  17  Platelets      407 non-null    float64
#  18  Prothrombin    416 non-null    float64
#  19  Stage          412 non-null    float64
# dtypes: float64(10), int64(3), object(7)
# memory usage: 65.4+ KB

# %% [markdown]
# Counting number of nulls

# %%
df.isnull().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
df.describe().transpose().style.background_gradient(cmap = 'GnBu')
# Out:
# <style type="text/css">
# #T_dd199_row0_col0, #T_dd199_row1_col0, #T_dd199_row2_col0, #T_dd199_row2_col1, #T_dd199_row2_col2, #T_dd199_row2_col3, #T_dd199_row2_col4, #T_dd199_row2_col5, #T_dd199_row2_col6, #T_dd199_row2_col7, #T_dd199_row3_col0, #T_dd199_row5_col0 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_dd199_row0_col1, #T_dd199_row0_col5 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_dd199_row0_col2 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_dd199_row0_col3, #T_dd199_row3_col1, #T_dd199_row3_col2, #T_dd199_row3_col3, #T_dd199_row3_col4, #T_dd199_row3_col5, #T_dd199_row3_col6, #T_dd199_row3_col7, #T_dd199_row5_col1, #T_dd199_row5_col2, #T_dd199_row5_col3, #T_dd199_row5_col4, #T_dd199_row5_col5, #T_dd199_row5_col6, #T_dd199_row5_col7, #T_dd199_row6_col3, #T_dd199_row6_col4, #T_dd199_row6_col5, #T_dd199_row8_col3, #T_dd199_row9_col0, #T_dd199_row9_col3, #T_dd199_row11_col1, #T_dd199_row11_col2, #T_dd199_row11_col3, #T_dd199_row11_col4, #T_dd199_row11_col5, #T_dd199_row11_col6, #T_dd199_row11_col7, #T_dd199_row12_col1, #T_dd199_row12_col2, #T_dd199_row12_col3, #T_dd199_row12_col4, #T_dd199_row12_col5, #T_dd199_row12_col6, #T_dd199_row12_col7 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_dd199_row0_col4, #T_dd199_row1_col3, #T_dd199_row6_col1, #T_dd199_row6_col6, #T_dd199_row8_col1, #T_dd199_row8_col4, #T_dd199_row8_col5, #T_dd199_row8_col6, #T_dd199_row9_col1, #T_dd199_row9_col4, #T_dd199_row9_col5, #T_dd199_row9_col6, #T_dd199_row10_col3 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_dd199_row0_col6, #T_dd199_row0_col7, #T_dd199_row4_col0, #T_dd199_row4_col3, #T_dd199_row8_col2, #T_dd199_row10_col1, #T_dd199_row10_col4, #T_dd199_row10_col5, #T_dd199_row10_col6 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_dd199_row1_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_dd199_row1_col2 {
#   background-color: #c0e6c0;
#   color: #000000;
# }
# #T_dd199_row1_col4, #T_dd199_row7_col5 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_dd199_row1_col5, #T_dd199_row7_col6 {
#   background-color: #e6f6e1;
#   color: #000000;
# }
# #T_dd199_row1_col6 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_dd199_row1_col7 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_dd199_row4_col1, #T_dd199_row6_col2, #T_dd199_row6_col7, #T_dd199_row9_col7 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# #T_dd199_row4_col2, #T_dd199_row4_col7 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_dd199_row4_col4, #T_dd199_row4_col5, #T_dd199_row4_col6, #T_dd199_row8_col7, #T_dd199_row9_col2 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_dd199_row6_col0 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_dd199_row7_col0, #T_dd199_row8_col0 {
#   background-color: #d1edca;
#   color: #000000;
# }
# #T_dd199_row7_col1 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# #T_dd199_row7_col2 {
#   background-color: #65c0cb;
#   color: #000000;
# }
# #T_dd199_row7_col3 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_dd199_row7_col4 {
#   background-color: #edf8e7;
#   color: #000000;
# }
# #T_dd199_row7_col7 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_dd199_row10_col0 {
#   background-color: #08599c;
#   color: #f1f1f1;
# }
# #T_dd199_row10_col2, #T_dd199_row10_col7 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_dd199_row11_col0 {
#   background-color: #084485;
#   color: #f1f1f1;
# }
# #T_dd199_row12_col0 {
#   background-color: #084e90;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dd199_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd199_level0_row0" class="row_heading level0 row0" >ID</th>
#       <td id="T_dd199_row0_col0" class="data row0 col0" >418.000000</td>
#       <td id="T_dd199_row0_col1" class="data row0 col1" >209.500000</td>
#       <td id="T_dd199_row0_col2" class="data row0 col2" >120.810458</td>
#       <td id="T_dd199_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_dd199_row0_col4" class="data row0 col4" >105.250000</td>
#       <td id="T_dd199_row0_col5" class="data row0 col5" >209.500000</td>
#       <td id="T_dd199_row0_col6" class="data row0 col6" >313.750000</td>
#       <td id="T_dd199_row0_col7" class="data row0 col7" >418.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dd199_level0_row1" class="row_heading level0 row1" >N_Days</th>
#       <td id="T_dd199_row1_col0" class="data row1 col0" >418.000000</td>
#       <td id="T_dd199_row1_col1" class="data row1 col1" >1917.782297</td>
#       <td id="T_dd199_row1_col2" class="data row1 col2" >1104.672992</td>
#       <td id="T_dd199_row1_col3" class="data row1 col3" >41.000000</td>
#       <td id="T_dd199_row1_col4" class="data row1 col4" >1092.750000</td>
#       <td id="T_dd199_row1_col5" class="data row1 col5" >1730.000000</td>
#       <td id="T_dd199_row1_col6" class="data row1 col6" >2613.500000</td>
#       <td id="T_dd199_row1_col7" class="data row1 col7" >4795.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dd199_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_dd199_row2_col0" class="data row2 col0" >418.000000</td>
#       <td id="T_dd199_row2_col1" class="data row2 col1" >18533.351675</td>
#       <td id="T_dd199_row2_col2" class="data row2 col2" >3815.845055</td>
#       <td id="T_dd199_row2_col3" class="data row2 col3" >9598.000000</td>
#       <td id="T_dd199_row2_col4" class="data row2 col4" >15644.500000</td>
#       <td id="T_dd199_row2_col5" class="data row2 col5" >18628.000000</td>
#       <td id="T_dd199_row2_col6" class="data row2 col6" >21272.500000</td>
#       <td id="T_dd199_row2_col7" class="data row2 col7" >28650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dd199_level0_row3" class="row_heading level0 row3" >Bilirubin</th>
#       <td id="T_dd199_row3_col0" class="data row3 col0" >418.000000</td>
#       <td id="T_dd199_row3_col1" class="data row3 col1" >3.220813</td>
#       <td id="T_dd199_row3_col2" class="data row3 col2" >4.407506</td>
#       <td id="T_dd199_row3_col3" class="data row3 col3" >0.300000</td>
#       <td id="T_dd199_row3_col4" class="data row3 col4" >0.800000</td>
#       <td id="T_dd199_row3_col5" class="data row3 col5" >1.400000</td>
#       <td id="T_dd199_row3_col6" class="data row3 col6" >3.400000</td>
#       <td id="T_dd199_row3_col7" class="data row3 col7" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dd199_level0_row4" class="row_heading level0 row4" >Cholesterol</th>
#       <td id="T_dd199_row4_col0" class="data row4 col0" >284.000000</td>
#       <td id="T_dd199_row4_col1" class="data row4 col1" >369.510563</td>
#       <td id="T_dd199_row4_col2" class="data row4 col2" >231.944545</td>
#       <td id="T_dd199_row4_col3" class="data row4 col3" >120.000000</td>
#       <td id="T_dd199_row4_col4" class="data row4 col4" >249.500000</td>
#       <td id="T_dd199_row4_col5" class="data row4 col5" >309.500000</td>
#       <td id="T_dd199_row4_col6" class="data row4 col6" >400.000000</td>
#       <td id="T_dd199_row4_col7" class="data row4 col7" >1775.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dd199_level0_row5" class="row_heading level0 row5" >Albumin</th>
#       <td id="T_dd199_row5_col0" class="data row5 col0" >418.000000</td>
#       <td id="T_dd199_row5_col1" class="data row5 col1" >3.497440</td>
#       <td id="T_dd199_row5_col2" class="data row5 col2" >0.424972</td>
#       <td id="T_dd199_row5_col3" class="data row5 col3" >1.960000</td>
#       <td id="T_dd199_row5_col4" class="data row5 col4" >3.242500</td>
#       <td id="T_dd199_row5_col5" class="data row5 col5" >3.530000</td>
#       <td id="T_dd199_row5_col6" class="data row5 col6" >3.770000</td>

# %% [markdown]
# Age column in the dataset is in terms of days, convert it to years

# %%
df["Age"]=(df['Age']/365).astype("int64")
df["Age"]
# Out:
# 0      58
# 1      56
# 2      70
# 3      54
# 4      38
#        ..
# 413    67
# 414    39
# 415    57
# 416    58
# 417    53
# Name: Age, Length: 418, dtype: int64

# %% [markdown]
# Since ID is not a necessary attribute and has many null values and is not a very required feature, we will drop it

# %%
df=df.drop('ID',axis=1)
df.columns
# Out:
# Index(['N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites', 'Hepatomegaly',
#        'Spiders', 'Edema', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
#        'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin',
#        'Stage'],
#       dtype='object')

# %% [markdown]
# Graph of null values in dataset

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df.isnull(),cmap='BuPu',vmin=0.5, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Percentage of missing values

# %%
count = 0
len_df = 0
for col in df.columns:
    null = 0
    l = 0
    null = df[col].isnull().sum()
    l = len(df[col])
    count=count+ null
    len_df = len_df + l
print('Percentage of missing Values: ', np.ceil(100*count/len_df))
# Out:
# Percentage of missing Values:  14.0

# %% [markdown]
# Print columns based on missing values

# %%
df_missing_values = pd.DataFrame({'percentage':round((df.isnull().mean())*100,4)})
df_missing_values.sort_values(by = 'percentage', ascending = False).style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_d285c_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d285c_row1_col0 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_d285c_row2_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_d285c_row3_col0, #T_d285c_row4_col0, #T_d285c_row5_col0, #T_d285c_row6_col0, #T_d285c_row7_col0, #T_d285c_row8_col0 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_d285c_row9_col0 {
#   background-color: #148a66;
#   color: #f1f1f1;
# }
# #T_d285c_row10_col0 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_d285c_row11_col0 {
#   background-color: #038166;
#   color: #f1f1f1;
# }
# #T_d285c_row12_col0, #T_d285c_row13_col0, #T_d285c_row14_col0, #T_d285c_row15_col0, #T_d285c_row16_col0, #T_d285c_row17_col0, #T_d285c_row18_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d285c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d285c_level0_row0" class="row_heading level0 row0" >Tryglicerides</th>
#       <td id="T_d285c_row0_col0" class="data row0 col0" >32.535900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row1" class="row_heading level0 row1" >Cholesterol</th>
#       <td id="T_d285c_row1_col0" class="data row1 col0" >32.057400</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row2" class="row_heading level0 row2" >Copper</th>
#       <td id="T_d285c_row2_col0" class="data row2 col0" >25.837300</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row3" class="row_heading level0 row3" >Drug</th>
#       <td id="T_d285c_row3_col0" class="data row3 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row4" class="row_heading level0 row4" >Ascites</th>
#       <td id="T_d285c_row4_col0" class="data row4 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row5" class="row_heading level0 row5" >Hepatomegaly</th>
#       <td id="T_d285c_row5_col0" class="data row5 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row6" class="row_heading level0 row6" >Spiders</th>
#       <td id="T_d285c_row6_col0" class="data row6 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row7" class="row_heading level0 row7" >SGOT</th>
#       <td id="T_d285c_row7_col0" class="data row7 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row8" class="row_heading level0 row8" >Alk_Phos</th>
#       <td id="T_d285c_row8_col0" class="data row8 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row9" class="row_heading level0 row9" >Platelets</th>
#       <td id="T_d285c_row9_col0" class="data row9 col0" >2.631600</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row10" class="row_heading level0 row10" >Stage</th>
#       <td id="T_d285c_row10_col0" class="data row10 col0" >1.435400</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row11" class="row_heading level0 row11" >Prothrombin</th>
#       <td id="T_d285c_row11_col0" class="data row11 col0" >0.478500</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row12" class="row_heading level0 row12" >N_Days</th>
#       <td id="T_d285c_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row13" class="row_heading level0 row13" >Albumin</th>
#       <td id="T_d285c_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row14" class="row_heading level0 row14" >Status</th>
#       <td id="T_d285c_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row15" class="row_heading level0 row15" >Edema</th>
#       <td id="T_d285c_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row16" class="row_heading level0 row16" >Sex</th>
#       <td id="T_d285c_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row17" class="row_heading level0 row17" >Age</th>
#       <td id="T_d285c_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d285c_level0_row18" class="row_heading level0 row18" >Bilirubin</th>
#       <td id="T_d285c_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# selecting categorical and numeric columns

# %%
categorical= df.select_dtypes(["object"]).columns
categorical
# Out:
# Index(['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema'], dtype='object')

# %%
numerical= df.select_dtypes(["float64","int64"]).columns
numerical
# Out:
# Index(['N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
#        'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin',
#        'Stage'],
#       dtype='object')

# %% [markdown]
# Handling the Missing Values

# %%
#for categorical data, fill the missing value with mode
for j in categorical:
    df[j].fillna(df[j].mode().values[0], inplace=True)

# %%
#for numerical data, fill the missing value with median
for j in numerical:
    df[j].fillna(df[j].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %% [markdown]
# Correlations and pairplots

# %%
sns.pairplot(df)

# %%
correlation=df.corr()
sns.heatmap(correlation, cmap="PuBu",annot=True)

# %% [markdown]
# Counting disticnt categorical features.
# Since stage is a multiclass feature, let us make it binary by making stages 0,1,2,3 as NO CIRRHOSIS i.e. 0 and stage 4 to 1 i.e. CIRRHOSIS

# %%
df['Stage']=df['Stage'].replace([0,1,2,3],0)

# %%
df['Stage']=df['Stage'].replace(4,1)

# %%
df['Stage']=df['Stage'].astype("int64")

# %%
df.head()
# Out:
#    N_Days Status             Drug  Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0     400      D  D-penicillamine   58   F       Y            Y       Y     Y
# 1    4500      C  D-penicillamine   56   F       N            Y       Y     N
# 2    1012      D  D-penicillamine   70   M       N            N       N     S
# 3    1925      D  D-penicillamine   54   F       N            Y       Y     S
# 4    1504     CL          Placebo   38   F       N            Y       Y     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0       14.5        261.0     2.60   156.0    1718.0  137.95          172.0
# 1        1.1        302.0     4.14    54.0    7394.8  113.52           88.0
# 2        1.4        176.0     3.48   210.0     516.0   96.10           55.0
# 3        1.8        244.0     2.54    64.0    6121.8   60.63           92.0
# 4        3.4        279.0     3.53   143.0     671.0  113.15           72.0
#
#    Platelets  Prothrombin  Stage
# 0      190.0         12.2      1
# 1      221.0         10.6      0
# 2      151.0         12.0      1
# 3      183.0         10.3      1
# 4      136.0         10.9      0

# %%
for i in categorical:
    sns.countplot(x=df[i], hue='Stage', data =df)
    plt.show()

# %% [markdown]
# ## ML Model

# %% [markdown]
# Importing ML model modules

# %%
from sklearn.metrics import confusion_matrix
from lightgbm import LGBMClassifier
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Selecting descriptive features and target features

# %%
X=df.iloc[:,:-1].values
y=df.loc[:,'Stage'].values

# %% [markdown]
# Label Encoding the Categorical Data

# %%
X

# %%
le1 = LabelEncoder()
for i in [1,2,4,5,6,7,8]:
  X[:,i] = le1.fit_transform(X[:,i])

# %%
df_X=pd.DataFrame(X)
df_X.head()

# %%
df_y=pd.DataFrame(y)
df_y.head()

# %% [markdown]
# Splitting The Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=25, random_state=0)
# define the datasets to evaluate each iteration
evalset = [(X_train, y_train), (X_test,y_test)]

# %%
lgb_model = LGBMClassifier()
lgb_model.fit(X_train,y_train)

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores, fit_times, _ = learning_curve(lgb_model, X, y, cv=30,return_times=True)
plt.plot(train_sizes,np.mean(train_scores,axis=1))

# %% [markdown]
# Predicting Values

# %%
y_pred=lgb_model.predict(X_test)

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# Accuracy score

# %%
from sklearn.metrics import accuracy_score as ascore
print("Accuracy of LGB Classifier optimized is: ",ascore(y_test,y_pred)*100,"%")

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred, labels=lgb_model.classes_)
cm

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=lgb_model.classes_)
disp.plot()

# %% [markdown]
# Precission - Recall

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(y_pred,y_test)

# %%
print("Precision: ",precision)
print("Recall: ",recall)
print("Thresholds: ",thresholds)

# %%
fig, ax = plt.subplots()
ax.plot(recall, precision, color='purple')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# AUC Curve

# %%
from sklearn.metrics import roc_auc_score
print("ROC Accuracy score is: ",roc_auc_score(y, lgb_model.predict_proba(X)[:, 1])*100,"%")

# %%
from sklearn import metrics as m
m.plot_roc_curve(lgb_model, X_test, y_test)
